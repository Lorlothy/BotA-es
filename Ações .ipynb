# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
import pandas as pd

navegador = webdriver.Chrome()

navegador.get("https://www.google.com")
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('ASAI3')
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)
cotacao_asai3 = navegador.find_element(By.XPATH, '//*[@id="knowledge-finance-wholepage__entity-summary"]/div[3]/g-card-section/div/g-card-section/div[2]/div[1]/span[1]/span/span[1]').text
cotacao_asai3 = cotacao_asai3.replace("," , ".")


navegador.get("https://www.google.com")
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('BBDC4')
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)
cotacao_BBDC4 = navegador.find_element(By.XPATH, '//*[@id="knowledge-finance-wholepage__entity-summary"]/div[3]/g-card-section/div/g-card-section/div[2]/div[1]/span[1]/span/span[1]').text
cotacao_BBDC4 = cotacao_BBDC4.replace("," , ".")

navegador.get("https://www.google.com")
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('BRKM5')
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)
cotacao_BRKM5 = navegador.find_element(By.XPATH, '//*[@id="knowledge-finance-wholepage__entity-summary"]/div[3]/g-card-section/div/g-card-section/div[2]/div[1]/span[1]/span/span[1]').text
cotacao_BRKM5 = cotacao_BRKM5.replace("," , ".")

navegador.get("https://www.google.com")
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('BRML3')
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)
cotacao_BRML3 = navegador.find_element(By.XPATH, '//*[@id="knowledge-finance-wholepage__entity-summary"]/div[3]/g-card-section/div/g-card-section/div[2]/div[1]/span[1]/span/span[1]').text
cotacao_BRML3 = cotacao_BRML3.replace("," , ".")

navegador.get("https://www.google.com")
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('VIVT3')
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)
cotacao_VIVT3 = navegador.find_element(By.XPATH, '//*[@id="knowledge-finance-wholepage__entity-summary"]/div[3]/g-card-section/div/g-card-section/div[2]/div[1]/span[1]/span/span[1]').text
cotacao_VIVT3 = cotacao_VIVT3.replace("," , ".")

navegador.get("https://www.google.com")
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('JHSF3')
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)
cotacao_JHSF3 = navegador.find_element(By.XPATH, '//*[@id="knowledge-finance-wholepage__entity-summary"]/div[3]/g-card-section/div/g-card-section/div[2]/div[1]/span[1]/span/span[1]').text
cotacao_JHSF3 = cotacao_JHSF3.replace("," , ".")

navegador.get("https://www.google.com")
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('MRFG3')
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)
cotacao_MRFG3 = navegador.find_element(By.XPATH, '//*[@id="knowledge-finance-wholepage__entity-summary"]/div[3]/g-card-section/div/g-card-section/div[2]/div[1]/span[1]/span/span[1]').text
cotacao_MRFG3 = cotacao_MRFG3.replace("," , ".")

navegador.get("https://www.google.com")
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('PRIO3')
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)
cotacao_PRIO3 = navegador.find_element(By.XPATH, '//*[@id="knowledge-finance-wholepage__entity-summary"]/div[3]/g-card-section/div/g-card-section/div[2]/div[1]/span[1]/span/span[1]').text
cotacao_PRIO3 = cotacao_PRIO3.replace("," , ".")

navegador.get("https://www.google.com")
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('SLCE3')
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)
cotacao_SLCE3 = navegador.find_element(By.XPATH, '//*[@id="knowledge-finance-wholepage__entity-summary"]/div[3]/g-card-section/div/g-card-section/div[2]/div[1]/span[1]/span/span[1]').text
cotacao_SLCE3 = cotacao_SLCE3.replace("," , ".")

navegador.get("https://www.google.com")
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('VALE3')
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)
cotacao_VALE3 = navegador.find_element(By.XPATH, '//*[@id="knowledge-finance-wholepage__entity-summary"]/div[3]/g-card-section/div/g-card-section/div[2]/div[1]/span[1]/span/span[1]').text
cotacao_VALE3 = cotacao_VALE3.replace("," , ".")


tabela = pd.read_excel("Acao.xlsx")

tabela.loc[tabela["Ação"] == "ASAI3", "Valor Fracionado"] = float(cotacao_asai3)
tabela.loc[tabela["Ação"] == "BBDC4", "Valor Fracionado"] = float(cotacao_BBDC4)
tabela.loc[tabela["Ação"] == "BRKM5", "Valor Fracionado"] = float(cotacao_BRKM5)
tabela.loc[tabela["Ação"] == "BRML3", "Valor Fracionado"] = float(cotacao_BRML3)
tabela.loc[tabela["Ação"] == "VIVT3", "Valor Fracionado"] = float(cotacao_VIVT3)
tabela.loc[tabela["Ação"] == "JHSF3", "Valor Fracionado"] = float(cotacao_JHSF3)
tabela.loc[tabela["Ação"] == "MRFG3", "Valor Fracionado"] = float(cotacao_MRFG3)
tabela.loc[tabela["Ação"] == "PRIO3", "Valor Fracionado"] = float(cotacao_PRIO3)
tabela.loc[tabela["Ação"] == "SLCE3", "Valor Fracionado"] = float(cotacao_SLCE3)
tabela.loc[tabela["Ação"] == "VALE3", "Valor Fracionado"] = float(cotacao_VALE3)

tabela["Valor Cheio"] = tabela["Valor Fracionado"] * tabela["Fracionado"]
tabela["Valor Fracionado5"] = tabela["Valor Fracionado"] * tabela["x5"]
tabela["Valor Fracionado10"] = tabela["Valor Fracionado"] * tabela["x10"]

tabela.loc[0, "Total Fracionado"] = sum(tabela["Valor Fracionado"])
tabela.loc[0, "Total Cheio"] = sum(tabela["Valor Cheio"])
tabela.loc[0, "Total x5"] = sum(tabela["Valor Fracionado5"])
tabela.loc[0, "Total x10"] = sum(tabela["Valor Fracionado10"])

tabela["Valor Cheio"] = tabela["Valor Cheio"].map("R${:.2f}".format)
tabela["Valor Cheio"] = tabela["Valor Fracionado"].map("R${:.2f}".format)

display(tabela)

navegador.quit()

tabela.to_excel("Acao Nova.xlsx", index=False)
# Out:
#     Ação  Valor Fracionado Valor Cheio  Fracionado  Valor Fracionado5  \
# 0  ASAI3             15.74     R$15.74         100              78.70
# 1  BBDC4             19.83     R$19.83         100              99.15
# 2  BRKM5             44.07     R$44.07         100             220.35
# 3  BRML3              9.16      R$9.16         100              45.80
# 4  VIVT3             50.14     R$50.14         100             250.70
# 5  JHSF3              7.05      R$7.05         100              35.25
# 6  MRFG3             15.33     R$15.33         100              76.65
# 7  PRIO3             27.32     R$27.32         100             136.60
# 8  SLCE3             55.64     R$55.64         100             278.20
# 9  VALE3             80.60     R$80.60         100             403.00
#
#    Valor Fracionado10  x5  x10  Unnamed: 8 Unnamed: 9  Total Fracionado  \
# 0               157.4   5   10         NaN      Total            324.88
# ...
